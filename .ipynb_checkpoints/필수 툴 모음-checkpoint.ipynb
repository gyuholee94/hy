# %%
# 필요한 라이브러리 임포트&설치
# !pip install sklearn
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import pickle
import re
from tqdm.notebook import tqdm
import platform
platform.system()
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# %config InlineBackend.figure_format = 'retina'

# ---
#기본체크
k = a.copy()
k.info()
k.describe()
k.hist(figsize=(10,10), bins=50)

#추세선?보기
from scipy import stats
plt.figure(figsize=(15,15))
stats.probplot(housing['price'], plot=plt)

#분포보기
plt.figure(figsize=(10,5))
sns.distplot(housing['price'], rug=True, rug_kws={'alpha': 0.05})

#산점도보기
sns.pairplot(new_housing)

#히트맵보기
plt.figure(figsize=(15,15))
sns.heatmap(housing[columns].corr(), square=True, fmt=".2f",annot=True)

# ---
#64비트 숫자로 바꾸기
pd.to_numeric(df_total['C행정구역(동읍면)별'].str.strip("'")) 

#숫자로 그냥바꾸기
dong_pop_df['성별'] = dong_pop_df['성별'].astype(int)

#인덱스새로
df.reset_index(inplace=True)
df_need = df.rename(columns=df.iloc[0]).drop(df.index[0])

#없애는거
for i in dong_pop_need.columns:
    dong_pop_need[f'{i}'] = dong_pop_need[f'{i}'].str.strip('`')

#가지고 있는거    
dong_pop_need = dong_pop_need[dong_pop_need['연령'].str.contains('1519|2024|2529|3034|3539|4044|4549|5054|5559|6064')]

#인덱스 새로하고 있던거지우기
dong_pop_df.reset_index(inplace=True, drop=True)

# 단순 체크
isnull
drop_duplicates
sort_values(by='asdf', ascending=True)

#그룹바이하고 썸
dong_ele_pop_df = dong_ele_pop_need.groupby(['행정동코드','행정동']).sum()
df.fillna('asd')
len(df.groupby(['asdf']).sum())

#값 바꾸기
dong_pop = dong_pop.replace({'행정동명': '종로5.6가동'}, {'행정동명': '종로5·6가동'})

#merge
kkk = pd.merge(a, b, on='asdf')

# re가지고 바꾸고 타입바꾸기
married_rate_need.이혼 = married_rate_need.이혼.apply(lambda x: re.sub(',','', x))
married_rate_need.계 = married_rate_need.계.apply(lambda x: re.sub('-','0', x)).astype(int)

#str으로 바꾸고 적용
sns.histplot(final_df['돌봄 틈새공백 인구'], color='#003458').set_title("돌봄틈새공백 인구분포 히스토그램")
#----------
from sklearn.model_selection import train_test_split
X = housing.drop('price', axis=1)
y = housing['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=32, test_size=0.25)
# ----------
#f스트링 활용
def NCP(route, dong):
    target = pklopen(f'{route}')
    target = target[target.행정동==f'{dong}']

#datetime
weekdays['Month'] = weekdays['기준일자'].dt.month
weekdays['Week'] = weekdays['기준일자'].dt.week
weekdays19 = weekdays[weekdays.기준일자.dt.year==2019]
weekdays20 = weekdays[weekdays.기준일자.dt.year==2020]

#반올림
weekday20N_corr = round(sum(total_num_corr)/len(total_num_corr), 2)

#간단 막대그래프
plt.figure(figsize=(10, 5))
plt.bar(index_list, ppl_cardnum, 
        color='midnightblue', 
        width=0.5,
        alpha=0.5,
       ) 
#sns 막대그래프
sns.barplot(
    data= corona,
    x= "연령",
    y= "연령별 인구 수"
)
plt.title('연령별 인구 분포')
plt.show()

#중간에 띄워주기
for index,num in zip(index_list, ppl_cardnum): 
    plt.text(index, num, str(num), horizontalalignment='center', fontsize=15) 
plt.title('유동인구&카드이용건수 상관관계', fontsize=20)
plt.xticks(fontsize=15 )
plt.grid(True, axis='y')
plt.show()
# Out:
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\gyuho\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-39796e1124a5> in <module>
#      20 # ---
#      21 #기본체크
# ---> 22 k = a.copy()
#      23 k.info()
#      24 k.describe()
#
# NameError: name 'a' is not defined
